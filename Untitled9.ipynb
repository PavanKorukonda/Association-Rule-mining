# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanKorukonda/Association-Rule-mining/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Name:** Korukonda Pavan Mourya
# # **Reg No:** 25020973

# %% [markdown]
# # **Dataset:** World Happiness Report
#
# # **Year:** 2017

# %% [markdown]
# # 3a) Write a python script to:

# %% [markdown]
# i) Read the dataset into pandas DataFrame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/2017.csv")

# %%
df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %% [markdown]
# The above dataset is "World Happiness report of the year 2017" and the dataset is consisting of 155 rows and 12 columns. In the dataset we are having a data of 154 countries.

# %% [markdown]
# ii) Identify and clean missing values.

# %%
missing = df.isnull().sum()
print(f"Missing values in each column:")
print(missing)
data_clean = df.fillna(df.mean(numeric_only=True))
print("\nMissing values after cleaning:", data_clean.isnull().sum().sum())
# Out:
# Missing values in each column:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64
#
# Missing values after cleaning: 0

# %% [markdown]
# There are no missing values or null values in the dataset so after data cleaning also the dataset will remain same.

# %% [markdown]
# iii) Calculate summary Statistics

# %%
print("SUMMARY STATISTICS")

# For Happiness Score
if 'Happiness.Score' in data_clean.columns:
    happiness = data_clean['Happiness.Score']
    print("\nHappiness Score:")
    print(f"  Mean: {happiness.mean():.4f}")
    print(f"  Median: {happiness.median():.4f}")
    print(f"  Standard Deviation: {happiness.std():.4f}")
    print(f"  Min: {happiness.min():.4f}, Max: {happiness.max():.4f}")
# For GDP per Capita
if 'Economy..GDP.per.Capita.' in data_clean.columns:
    gdp = data_clean['Economy..GDP.per.Capita.']
    print("\nGDP per Capita:")
    print(f"  Mean: {gdp.mean():.4f}")
    print(f"  Median: {gdp.median():.4f}")
    print(f"  Standard Deviation: {gdp.std():.4f}")
    print(f"  Min: {gdp.min():.4f}, Max: {gdp.max():.4f}")
# For Life Expectancy
if 'Health..Life.Expectancy.' in data_clean.columns:
    life = data_clean['Health..Life.Expectancy.']
    print("\nLife Expectancy:")
    print(f"  Mean: {life.mean():.4f}")
    print(f"  Median: {life.median():.4f}")
    print(f"  Standard Deviation: {life.std():.4f}")
    print(f"  Min: {life.min():.4f}, Max: {life.max():.4f}")
# Out:
# SUMMARY STATISTICS
#
# Happiness Score:
#   Mean: 5.3540
#   Median: 5.2790
#   Standard Deviation: 1.1312
#   Min: 2.6930, Max: 7.5370
#
# GDP per Capita:
#   Mean: 0.9847
#   Median: 1.0646
#   Standard Deviation: 0.4208
#   Min: 0.0000, Max: 1.8708
#
# Life Expectancy:
#   Mean: 0.5513
#   Median: 0.6060
#   Standard Deviation: 0.2371
#   Min: 0.0000, Max: 0.9495

# %% [markdown]
# We calculated the summary statistics i.e., Mean, Median and Standard Deviation for all the countries of columns: Happiness Score, GDP per Capita, Life expectancy.

# %% [markdown]
# # 3b) Using the same dataset

# %% [markdown]
# i) Create a new dataframe to store Country, GDP per Capita, Happiness score

# %%
df = pd.read_csv('2017.csv')
new_df = df[['Country', 'Economy..GDP.per.Capita.', 'Happiness.Score']]
print(new_df)
# Out:
#                       Country  Economy..GDP.per.Capita.  Happiness.Score
# 0                      Norway                  1.616463            7.537
# 1                     Denmark                  1.482383            7.522
# 2                     Iceland                  1.480633            7.504
# 3                 Switzerland                  1.564980            7.494
# 4                     Finland                  1.443572            7.469
# ..                        ...                       ...              ...
# 150                    Rwanda                  0.368746            3.471
# 151                     Syria                  0.777153            3.462
# 152                  Tanzania                  0.511136            3.349
# 153                   Burundi                  0.091623            2.905
# 154  Central African Republic                  0.000000            2.693
#
# [155 rows x 3 columns]

# %% [markdown]
# from the original dataset, we created another new dataframe of all the countries having only columns to store Country, GDP per Capita, Happiness Score.

# %% [markdown]
# ii) Write a function to filter out countries with a happiness Score greater than 7.0

# %%
def get_happy_countries():
    return df[df['Happiness.Score'] > 7][['Country', 'Happiness.Score']]

result = get_happy_countries()
print(result)
# Out:
#         Country  Happiness.Score
# 0        Norway            7.537
# 1       Denmark            7.522
# 2       Iceland            7.504
# 3   Switzerland            7.494
# 4       Finland            7.469
# 5   Netherlands            7.377
# 6        Canada            7.316
# 7   New Zealand            7.314
# 8        Sweden            7.284
# 9     Australia            7.284
# 10       Israel            7.213
# 11   Costa Rica            7.079
# 12      Austria            7.006

# %% [markdown]
# There are 12 countries from all 154 countries having Happiness Score Greater than 7.0

# %% [markdown]
# iii) Plot a bar chart of these countries Happiness Score using Matplotlib

# %%
happy_countries = df[df['Happiness.Score'] > 7.0]
plt.figure(figsize=(12, 8))
plt.bar(happy_countries['Country'], happy_countries['Happiness.Score'], color='skyblue')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('Countries with Happiness Score > 7.0 (2017)')
plt.xticks(rotation=45, ha='right')
plt.axhline(y=7.0, color='red', linestyle='--', linewidth=1, label='Threshold (7.0)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# In the previous step we calculated the number of countries having the Happiness Score greater than 7.0 now by using the matplotlib library we visualized these countries through barchart.

# %% [markdown]
# # 3c)Write a Python Program to:

# %% [markdown]
# i) Check for duplicate rows in the dataset

# %%
duplicates = df[df.duplicated()]

print(f"Total rows in dataset: {len(df)}")
print(f"Duplicate rows found: {len(duplicates)}")

if len(duplicates) > 0:
    print("\nDuplicate rows:")
    print(duplicates)
else:
    print("\nNo duplicate rows found in the dataset!")
# Out:
# Total rows in dataset: 155
# Duplicate rows found: 0
#
# No duplicate rows found in the dataset!

# %% [markdown]
# In the original dataset there are no duplicate rows present.

# %% [markdown]
# ii)Remove duplicate rows and save the cleaned dataset to a new CSV file

# %%
print(f"Original dataset shape: {df.shape}")
duplicate_count = df.duplicated().sum()
print(f"Duplicate rows found: {duplicate_count}")
df_clean = df.drop_duplicates()
print(f"Cleaned dataset shape: {df_clean.shape}")
print(f"Rows removed: {len(df) - len(df_clean)}")
df_clean.to_csv('2017_cleaned.csv', index=False)
print("Cleaned dataset saved as '2017_cleaned.csv'")
# Out:
# Original dataset shape: (155, 12)
# Duplicate rows found: 0
# Cleaned dataset shape: (155, 12)
# Rows removed: 0
# Cleaned dataset saved as '2017_cleaned.csv'

# %% [markdown]
# since there are no duplicate rows, after cleaning and creating the new csv file the dataset remains same as the original dataset.

# %% [markdown]
# # d) Using the dataset:

# %% [markdown]
# i) Create a lineplot using Matplotlib to show the Happiness Score over countries sorted alphabetically

# %%
df_sorted = df.sort_values('Country')
plt.figure(figsize=(14, 6))
plt.plot(df_sorted['Country'], df_sorted['Happiness.Score'],
         marker='o', linewidth=2, markersize=4, color='blue')
plt.xlabel('Country (Alphabetically Sorted)', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.title('Happiness Score by Country (Alphabetical Order)', fontsize=14, fontweight='bold')
plt.xticks(rotation=90, fontsize=8)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# For each and every country present in the dataset, we created a line plot using Matplotlib library for their Happiness Score.

# %% [markdown]
# ii) Create a bar chart for the Generosity values of the top 10 countries with the highest happiness score.

# %%
top_10 = df.nlargest(10, 'Happiness.Score')
plt.figure(figsize=(12, 6))
bars = plt.bar(top_10['Country'], top_10['Generosity'], color='orange')
plt.xlabel('Country')
plt.ylabel('Generosity')
plt.title('Generosity of Top 10 Happiest Countries (2017)')
plt.xticks(rotation=90, ha='right')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.001,
             f'{height:.3f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# In this step we calculaed the Generosity values for all the countries and we considered the top 10 countries having high generosity values. Next we did Data Visualization using Matplotlib Library of type bar chart.

# %% [markdown]
# # **2) Python Code for 2nd question**

# %%
import re
from collections import Counter

def process_text_file():
    # Create sample.txt
    try:
        with open('sample.txt', 'w') as f:
            f.write("Python is simple. Python is powerful. Python is fun.")
    except Exception as e:
        print(f"Error creating file: {e}")
        return

    # Read and process
    try:
        with open('sample.txt', 'r') as f:
            text = f.read()

        # Clean and count words
        words = re.findall(r'\b\w+\b', text.lower())
        word_count = Counter(words)

        # Save results
        with open('output.txt', 'w') as f:
            f.write("Original text:\n")
            f.write(text + "\n\n")
            f.write("Word frequency:\n")
            for word, count in sorted(word_count.items()):
                f.write(f"{word}: {count}\n")

        print("Processing complete!")
        print(f"Total unique words: {len(word_count)}")

    except FileNotFoundError:
        print("Error: File not found")
    except PermissionError:
        print("Error: Permission denied")
    except Exception as e:
        print(f"Error: {e}")

# Run the program
process_text_file()
# Out:
# Processing complete!
# Total unique words: 5

# %% [markdown]
# #**1) Python Code for 1st question**

# %% [markdown]
# 1a) Retrieve a student's details by roll number

# %%
students = {101: "Alice 85", 102: "Bob 78", 103: "Charlie 92", 104: "David 88", 105: "Eva 74"}

roll = int(input("Enter roll number: "))
print(f"Student: {students.get(roll, 'Not found')}")
# Out:
# Enter roll number: 103
# Student: Charlie 92

# %% [markdown]
# 1b)Calculate the average marks of all students

# %%
students = {
    101: 85,
    102: 78,
    103: 92,
    104: 88,
    105: 74
}

total = sum(students.values())
count = len(students)
average = total / count
print(f"Total students: {count}")
print(f"Total marks: {total}")
print(f"Average marks: {average:.2f}")
# Out:
# Total students: 5
# Total marks: 417
# Average marks: 83.40

# %% [markdown]
# 1c) Delete a student's record based on roll number.

# %%
students = {
    101: "Alice 85",
    102: "Bob 78",
    103: "Charlie 92",
    104: "David 88",
    105: "Eva 74"
}

print("Current students:", list(students.keys()))
roll_to_delete = int(input("\nEnter roll number to delete: "))
if roll_to_delete in students:
    del students[roll_to_delete]
    print(f"Student {roll_to_delete} deleted successfully!")
else:
    print(f"Student {roll_to_delete} not found")

print("\nRemaining students:", list(students.keys()))
# Out:
# Current students: [101, 102, 103, 104, 105]
#
# Enter roll number to delete: 103
# Student 103 deleted successfully!
#
# Remaining students: [101, 102, 104, 105]
